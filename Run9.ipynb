# %% [markdown]
# # Objective
#
# This run is using the updated game objectives and cleaned up a few bugs with the card costs. Currently a small bug still exists with the players losing gems somehow when taking gems in 0.1-1% of the games...

# %%
from game import Game
from ai import SplendorAI
from player import get_phase_parameters
from constants import *
from datetime import datetime
# from player import get_phase_parameters
import sys
from collections import defaultdict
from collections import Counter
# Out:
# /usr/local/lib/python3.5/dist-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
# simply used to initialize players
base_game = Game(id=0, n_players=4, players_compare_self_to_others=True)

# %%
from tensorflow.python.client import device_lib
print(device_lib.list_local_devices())
# Out:
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 11028711431967720468
# , name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 10210384282
# locality {
#   bus_id: 1
#   links {
#   }
# }
# incarnation: 14781665482042347213
# physical_device_desc: "device: 0, name: GeForce GTX 1080 Ti, pci bus id: 0000:01:00.0, compute capability: 6.1"
# ]

# %%
import tensorflow as tf
sess = tf.Session(config=tf.ConfigProto(log_device_placement=True))

# %%
# temperature will decrease over time
def calculate_temperature(round):
    return 1.9/(1 + round/1.2) /(1.5+round/1.1)/(1+round/5)

# %%
# constants to define; default
NETWORK_HYPERPARAMETERS = {
    # player input
    'player_funnel_layers': [15,12,10],
    'reserved_funnel_layers': [12,10,],
    'inject_reserved_at_player_funnel_index': 1, # 0 same as input, 1 = as first layer, etc.
    'card_funnel_layers': [12,12,8],
    # game input
    'game_funnel_layers': [15, 12, 10],
    'game_objective_funnel_layers': [10, 8],
    'game_card_funnel_layers': [15, 12, 10],
    # overall, slightly increased from default
    'main_dense_layers': [108, 52, 16], #this is when everything is combined

    # output layers
    # this does not include the win layer
    'output_layers': [
        {
            'name': 'Q1',
            'lag': 1,
            'score': 1,
            'discount': 0.1,
            'gems': 0.01,

        },
        {
            'name': 'Q3',
            'lag':  3,
            'score': 1,
            'discount': 0.1,
            'gems': 0,
        },
        {
            'name': 'Q5',
            'lag': 5,
            'score': 1,
            'discount': 0.05,
            'gems': 0,
        },
    ],
}

def get_phase_parameters(phase):
    """
    training will be divided into 5 phases

    """
    if phase==1:
        return {
            'Q1': 0.5,
            'Q3': 0.3,
            'Q5': 0.15,
            'win': 0.05,
        }
    elif phase==2:
        return {
            'Q1': 0.35,
            'Q3': 0.25,
            'Q5': 0.25,
            'win': 0.15,
        }
    elif phase==3:
        return {
            'Q1': 0.25,
            'Q3': 0.25,
            'Q5': 0.25,
            'win': 0.25,
        }
    elif phase==4:
        return {
            'Q1': 0.15,
            'Q3': 0.2,
            'Q5': 0.35,
            'win': 0.3,
        }
    elif phase==5:
        return {
            'Q1': 0.05,
            'Q3': 0.1,
            'Q5': 0.35,
            'win': 0.50,
        }
    elif phase==6:
        return {
            'Q1': 0.03,
            'Q3': 0.1,
            'Q5': 0.22,
            'win': 0.75
        }

# %%
players = base_game.players
game_data = defaultdict(list)
run_name='run_9'

# %%
def summarize_counters(counter_list):
    master_counter = Counter()
    n = len(counter_list)
    for counter in counter_list:
        master_counter.update(counter)
    keys = list(master_counter.keys())
    for k in sorted(keys):
        master_counter[k] /= n
    return master_counter

# %%
set_durations = {}

# %% [markdown]
# # Test multiple runs of games
#
# This should constitute the first half, and get a good idea of how successful these methods are

# %%
n_rounds = 9
n_sets_per_round = 3
n_simulations_per_set = 320

start_time = datetime.now()
for i in range(n_rounds):
    print('ON ROUND', i)
    phase = min(6, i // 2 + 1)
    temperature = calculate_temperature(i)
    
    for p_i, player in enumerate(players):
        player.temperature = temperature
        player.decision_weighting = get_phase_parameters(phase)
        
    for j in range(n_sets_per_round):
        set_start_time = datetime.now()
        for k in range(n_simulations_per_set):
            # if (i==0) and (j==0):
            #    # soft restart
            #    break
            new_game = Game(id=i*n_sets_per_round+n_simulations_per_set + j*n_simulations_per_set+k, 
                            players=players)
            stalemate = new_game.run()  
            # stalemates should be extraordinarily rare and pretty much nonexistent
            if stalemate: 
                very_long_game = new_game
                print('teaching ai not to stalemate -_-')
                for player in players:
                    player.transfer_history_to_ai()
                    player.ai.train_models(verbose=0,n_epochs=3)
            sys.stdout.write('.')
            sys.stdout.flush()
            # record historic game data for each set
            game_data[(i,j)].append(new_game.copy_plain_data_for_self_and_players())
        set_stop_time = datetime.now()
        duration = (set_start_time-set_stop_time).seconds
        for player in players:
            player.transfer_history_to_ai()
            # train more epochs this time to make better predictions
            player.ai.train_models(verbose=0, n_epochs=30, batch_size=1500)
        set_durations[(i,j,k)] = duration
        print('/')
        sys.stdout.flush()
        avg_game_length = np.mean([x['game']['turn'] for x in game_data[(i,j)]])
        print('R/S %d/%d AVERAGE GAME LENGTH: ' % (i, j), avg_game_length)
        avg_cards_purchased = np.mean([
            [
                pdata['n_cards'] 
                for pdata in x['players'].values()
            ] 
            for x in game_data[(i,j)]
        ]
        )
        print('R/S %d/%d AVERAGE CARDS PURCHASED: ' % (i, j), avg_cards_purchased)
        # calculate win rates
        player_data = [x['players'] for x in game_data[(i,j)]]
        win_values = [[player_data[idx][pid]['win'] for idx in range(n_simulations_per_set)] for pid in range(4)]
        win_rates = [np.mean(v) for v in win_values]
        print('WIN RATES: ', str(win_rates))
        # reservation averages
        reservation_counters = [
            [
                player_data[idx][pid]['total_times_reserved'] 
                for idx in range(n_simulations_per_set)
            ]
            for pid in range(4)
        ]
        print('RESERVATION SUMMARY: ', [summarize_counters(counters) for counters in reservation_counters])
        
        # gem taking averages
        gem_counters = [
            [
                player_data[idx][pid]['total_gems_taken'] 
                for idx in range(n_simulations_per_set)
            ]
            for pid in range(4)
        ]
        print('GEMS SUMMARY: ', [summarize_counters(counters) for counters in gem_counters])
                             
    for player in players:
        player.reset(reset_extended_history=True)
   
    
    for p_i, player in enumerate(players):
        model_name = '{run_name}_player_%s_'.format(run_name=run_name) % str(p_i)
        player.ai.save_models(model_name, index=i)
    
    
stop_time = datetime.now()
for time in [start_time, stop_time]:
    print(time.strftime('%x %X'))
    
# save historic data
import pickle
with open('{run_name}_game_data.dat'.format(run_name=run_name), 'wb') as f:
    pickle.dump(game_data, f)
    
with open('{run_name}_duration_data.dat'.format(run_name=run_name), 'wb') as f:
    pickle.dump(set_durations, f)
# Out:
# ON ROUND 0
# .........ERROR WITH NUMBER OF ROUNDS
# teaching ai not to stalemate -_-
# ......................................................................................................................................................................................................................................................................................................................./
# R/S 0/0 AVERAGE GAME LENGTH:  153.4125
# R/S 0/0 AVERAGE CARDS PURCHASED:  13.5609375
# WIN RATES:  [0.228125, 0.246875, 0.215625, 0.309375]

# RESERVATION SUMMARY:  [Counter({(3, 'board'): 1.23125, (1, 'board'): 1.20625, (2, 'board'): 1.178125, (3, 'topdeck'): 0.3125, (2, 'topdeck'): 0.303125, (1, 'topdeck'): 0.284375}), Counter({(2, 'board'): 1.31875, (3, 'board'): 1.225, (1, 'board'): 1.209375, (3, 'topdeck'): 0.334375, (2, 'topdeck'): 0.31875, (1, 'topdeck'): 0.278125}), Counter({(2, 'board'): 1.240625, (3, 'board'): 1.2125, (1, 'board'): 1.09375, (2, 'topdeck'): 0.30625, (3, 'topdeck'): 0.296875, (1, 'topdeck'): 0.240625}), Counter({(2, 'board'): 1.28125, (3, 'board'): 1.246875, (1, 'board'): 1.128125, (2, 'topdeck'): 0.315625, (3, 'topdeck'): 0.303125, (1, 'topdeck'): 0.278125})]
# GEMS SUMMARY:  [Counter({3: 7.5375, 0: 4.478125, 2: 4.084375, 1: 2.003125, -1: 0.15625, -2: 0.009375}), Counter({3: 7.825, 0: 4.0875, 2: 3.8625, 1: 2.015625, -1: 0.146875, -2: 0.0125}), Counter({3: 7.934375, 2: 3.91875, 0: 3.578125, 1: 1.8, -1: 0.140625}), Counter({3: 7.51875, 0: 4.040625, 2: 3.959375, 1: 1.865625, -1: 0.14375, -2: 0.003125, -3: 0.003125})]
# ON ROUND 1
# ................................................................................................................................................................................................................................................................................................................................/
# R/S 1/0 AVERAGE GAME LENGTH:  133.4375
# R/S 1/0 AVERAGE CARDS PURCHASED:  12.9859375
# WIN RATES:  [0.1375, 0.1375, 0.3, 0.425]
# RESERVATION SUMMARY:  [Counter({(3, 'board'): 1.24375, (2, 'board'): 1.221875, (1, 'board'): 1.159375, (3, 'topdeck'): 0.284375, (2, 'topdeck'): 0.278125, (1, 'topdeck'): 0.234375}), Counter({(3, 'board'): 1.234375, (2, 'board'): 1.196875, (1, 'board'): 1.115625, (2, 'topdeck'): 0.3125, (1, 'topdeck'): 0.303125, (3, 'topdeck'): 0.278125}), Counter({(3, 'board'): 1.26875, (1, 'board'): 1.259375, (2, 'board'): 1.228125, (2, 'topdeck'): 0.321875, (1, 'topdeck'): 0.2875, (3, 'topdeck'): 0.278125}), Counter({(3, 'board'): 1.375, (2, 'board'): 1.275, (1, 'board'): 1.003125, (2, 'topdeck'): 0.3, (3, 'topdeck'): 0.2875, (1, 'topdeck'): 0.24375})]
# GEMS SUMMARY:  [Counter({3: 7.559375, 2: 3.971875, 0: 3.61875, 1: 1.634375, -1: 0.121875, -2: 0.003125}), Counter({3: 7.5625, 2: 3.775, 0: 3.3375, 1: 1.621875, -1: 0.146875, -2: 0.00625, -3: 0.003125}), Counter({3: 7.740625, 2: 3.734375, 0: 2.7875, 1: 1.41875, -1: 0.121875}), Counter({3: 7.8, 2: 3.653125, 0: 2.53125, 1: 1.290625, -1: 0.05, -2: 0.009375, -3: 0.003125})]
# ................................................................................................................................................................................................................................................................................................................................/
# R/S 1/1 AVERAGE GAME LENGTH:  133.4625
# R/S 1/1 AVERAGE CARDS PURCHASED:  12.996875
# WIN RATES:  [0.109375, 0.115625, 0.296875, 0.484375]
# RESERVATION SUMMARY:  [Counter({(3, 'board'): 1
# GEMS SUMMARY:  [Counter({3: 7.4625, 2: 3.640625, 0: 3.6, 1: 1.496875, -1: 0.15, -2: 0.003125}), Counter({3: 7.553125, 2: 3.6125, 0: 3.390625, 1: 1.39375, -1: 0.153125, -2: 0.00625}), Counter({3: 7.49375, 2: 3.5375, 0: 2.303125, 1: 1.0875, -1: 0.075, -2: 0.003125}), Counter({3: 7.78125, 2: 3.39375, 0: 1.921875, 1: 0.896875, -1: 0.046875})]
# ON ROUND 3
# ................................................................................................................................................................................................................................................................................................................................/
# R/S 3/0 AVERAGE GAME LENGTH:  127.8125
# R/S 3/0 AVERAGE CARDS PURCHASED:  12.91015625
# WIN RATES:  [0.075, 0.071875, 0.30625, 0.55]
# RESERVATION SUMMARY:  [Counter({(3, 'board'): 1.284375, (2, 'board'): 1.128125, (1, 'board'): 1.009375, (3, 'topdeck'): 0.303125, (1, 'topdeck'): 0.246875, (2, 'topdeck'): 0.234375}), Counter({(3, 'board'): 1.246875, (2, 'board'): 1.1125, (1, 'board'): 1.021875, (3, 'topdeck'): 0.334375, (1, 'topdeck'): 0.265625, (2, 'topdeck'): 0.215625}), Counter({(3, 'board'): 1.590625, (2, 'board'): 1.234375, (1, 'board'): 0.853125, (3, 'topdeck'): 0.228125, (2, 'topdeck'): 0.209375, (1, 'topdeck'): 0.159375}), Counter({(3, 'board'): 1.7125, (2, 'board'): 1.384375, (1, 'board'): 0.6, (2, 'topdeck'): 0.16875, (3, 'topdeck'): 0.153125, (1, 'topdeck'): 0.1})]
# GEMS SUMMARY:  [Counter({3: 7.18125, 2: 3.928125, 0: 3.4875, 1: 1.509375, -1: 0.140625, -2: 0.00625}), Counter({3: 7.43125, 2: 3.675, 0: 3.609375, 1: 1.4, -1: 0.125, -2: 0.003125}), Counter({3: 7.740625, 2: 3.4375, 0: 2.35, 1: 1.0, -1: 0.090625, -2: 0.00625}), Counter({3: 7.55625, 2: 3.421875, 0: 1.503125, 1: 0.740625, -1: 0.03125})]
# ................................................................................................................................................................................................................................................................................................................................/
# R/S 3/1 AVERAGE GAME LENGTH:  126.85
# R/S 3/1 AVERAGE CARDS PURCHASED:  12.79609375
# WIN RATES:  [0.065625, 0.05625, 0.35, 0.53125]
# RESERVATION SUMMARY:  [Counter({(2, 'board'): 1.25625, (3, 'board'): 1.2, (1, 'board'): 1.015625, (2, 'topdeck'): 0.284375, (3, 'topdeck'): 0.2375, (1, 'topdeck'): 0.234375}), Counter({(3, 'board'): 1.221875, (2, 'board'): 1.190625, (1, 'board'): 1.1, (3, 'topdeck'): 0.259375, (2, 'topdeck'): 0.259375, (1, 'topdeck'): 0.225}), Counter({(3, 'board'): 1.490625, (2, 'board'): 1.175, (1, 'board'): 0.903125, (2, 'topdeck'): 0.275, (3, 'topdeck'): 0.234375, (1, 'topdeck'): 0.1875}), Counter({(3, 'board'): 1.784375, (2, 'board'): 1.2, (1, 'board'): 0.784375, (2, 'topdeck'): 0.165625, (3, 'topdeck'): 0.153125, (1, 'topdeck'): 0.15})]
# GEMS SUMMARY:  [Counter({3: 7.509375, 2: 3.61875, 0: 3.425, 1: 1.359375, -1: 0.153125, -2: 0.003125}), Counter({3: 7.315625, 2: 3.70625, 0: 3.65, 1: 1.571875, -1: 0.209375, -2: 0.00625, -3: 0.003125}), Counter({3: 7.584375, 2: 3.503125, 0: 2.184375, 1: 1.01875, -1: 0.078125}), Counter({3: 7.521875, 2: 3.284375, 0: 1.18125, 1: 0.765625, -1: 0.025})]
# ................................................................................................................................................................................................................................................................................................................................/
# R/S 3/2 AVERAGE GAME LENGTH:  127.7875
# R/S 3/2 AVERAGE CARDS PURCHASED:  12.8359375
# WIN RATES:  [0.059375, 0.03125, 0.465625, 0.44375]
# RESERVATION SUMMARY:  [Counter({(3, 'board'): 1.26875, (2, 'board'): 1.15625, (1, 'board'): 1.040625, (2, 'topdeck'): 0.290625, (3, 'topdeck'): 0.259375, (1, 'topdeck'): 0.240625}), Counter({(2, 'board'): 1.23125, (3, 'board'): 1.228125, (1, 'board'): 0.95, (2, 'topdeck'): 0.28125, (1, 'topdeck'): 0.271875, (3, 'topdeck'): 0.2625}), Counter({(3, 'board'): 1.525, (2, 'board'): 1.29375, (1, 'board'): 0.85, (2, 'topdeck'): 0.215625, (3, 'topdeck'): 0.2125, (1, 'topdeck'): 0.146875}), Counter({(3, 'board'): 1.759375, (2, 'board'): 1.146875, (1, 'board'): 0.74375, (2, 'topdeck'): 0.184375, (3, 'topdeck'): 0.165625, (1, 'topdeck'): 0.146875})]
# GEMS SUMMARY:  [Counter({3: 7.346875, 2: 3.821875, 0: 3.509375, 1: 1.571875, -1: 0.159375, -2: 0.0125}), Counter({3: 7.4, 2: 3.8125, 0: 3.64375, 1: 1.4875, -1: 0.134375, -2: 0.003125}), Counter({3: 7.390625, 2: 3.290625, 0: 2.328125, 1: 0.98125, -1: 0.046875}), Counter({3: 7.49375, 2: 3.634375, 0: 1.65625, 1: 0.81875, -1: 0.028125})]
# ON ROUND 4
# ................................................................................................................................................................................................................................................................................................................................/
# R/S 4/0 AVERAGE GAME LENGTH:  127.7375
# R/S 4/0 AVERAGE CARDS PURCHASED:  12.95859375
# WIN RATES:  [0.05, 0.075, 0.415625, 0.459375]
# RESERVATION SUMMARY:  [Counter({(2, 'board'): 1.1875, (3, 'board'): 1.16875, (1, 'board'): 1.0125, (3, 'topdeck'): 0.35, (2, 'topdeck'): 0.3, (1, 'topdeck'): 0.25625}), Counter({(3, 'board'): 1.278125, (2, 'board'): 1.209375, (1, 'board'): 1.0375, (2, 'topdeck'): 0.26875, (3, 'topdeck'): 0.253125, (1, 'topdeck'): 0.225}), Counter({(3, 'board'): 1.63125, (2, 'board'): 1.353125, (1, 'board'): 0.71875, (2, 'topdeck'): 0.18125, (1, 'topdeck'): 0.1625, (3, 'topdeck'): 0.15}), Counter({(3, 'board'): 1.80625, (2, 'board'): 1.146875, (1, 'board'): 0.73125, (3, 'topdeck'): 0.15625, (1, 'topdeck'): 0.1375, (2, 'topdeck'): 0.115625})]
# GEMS SUMMARY:  [Counter({3: 7.415625, 2: 3.803125, 0: 3.46875, 1: 1.453125, -1: 0.134375, -2: 0.003125}), Counter({3: 7.3375, 2: 3.96875, 0: 3.340625, 1: 1.3875, -1: 0.16875, -2: 0.0125}), Counter({3: 7.684375, 2: 3.509375, 0: 1.821875, 1: 0.890625, -1: 0.040625, -2: 0.003125}), Counter({3: 7.34375, 2: 3.684375, 0: 1.76875, 1: 0.771875, -1: 0.05, -2: 0.003125})]
# ................................................................................................................................................................................................................................................................................................................................/
# R/S 4/1 AVERAGE GAME LENGTH:  125.625
# R/S 4/1 AVERAGE CARDS PURCHASED:  12.93515625
# WIN RATES:  [0.06875, 0.125, 0.43125, 0.378125]
# RESERVATION SUMMARY:  [Counter({(3, 'board'): 1.275, (2, 'board'): 1.1625, (1, 'board'): 1.075, (2, 'topdeck'): 0.271875, (3, 'topdeck'): 0.253125, (1, 'topdeck'): 0.215625}), Counter({(3, 'board'): 1.259375, (2, 'board'): 1.175, (1, 'board'): 1.109375, (3, 'topdeck'): 0.3, (1, 'topdeck'): 0.28125, (2, 'topdeck'): 0.25}), Counter({(3, 'board'): 1.64375, (2, 'board'): 1.296875, (1, 'board'): 0.659375, (3, 'topdeck'): 0.121875, (1, 'topdeck'): 0.11875, (2, 'topdeck'): 0.11875}), Counter({(3, 'board'): 1.828125, (2, 'board'): 1.159375, (1, 'board'): 0.665625, (1, 'topdeck'): 0.153125, (3, 'topdeck'): 0.1375, (2, 'topdeck'): 0.11875})]
# GEMS SUMMARY:  [Counter({3: 7.221875, 2: 3.690625, 0: 3.48125, 1: 1.378125, -1: 0.15625, -2: 0.009375}), Counter({3: 7.309375, 2: 3.65625, 0: 3.165625, 1: 1.415625, -1: 0.178125, -2: 0.003125}), Counter({3: 7.690625, 2: 3.2625, 0: 1.58125, 1: 0.771875, -1: 0.025}), Counter({3: 7.41875, 2: 3.45, 0: 1.609375, 1: 0.734375, -1: 0.021875, -2: 0.003125})]
# ................................................................................................................................................................................................................................................................................................................................/
# R/S 4/2 AVERAGE GAME LENGTH:  126.1125
# R/S 4/2 AVERAGE CARDS PURCHASED:  12.90234375
# WIN RATES:  [0.084375, 0.121875, 0.421875, 0.3875]
# RESERVATION SUMMARY:  [Counter({(3, 'board'): 1.3125, (1, 'board'): 1.096875, (2, 'board'): 1.084375, (3, 'topdeck'): 0.275, (2, 'topdeck'): 0.259375, (1, 'topdeck'): 0.20625}), Counter({(3, 'board'): 1.290625, (2, 'board'): 1.1625, (1, 'board'): 1.096875, (3, 'topdeck'): 0.246875, (2, 'topdeck'): 0.240625, (1, 'topdeck'): 0.2375}), Counter({(3, 'board'): 1.696875, (2, 'board'): 1.11875, (1, 'board'): 0.765625, (3, 'topdeck'): 0.18125, (1, 'topdeck'): 0.171875, (2, 'topdeck'): 0.13125}), Counter({(3, 'board'): 1.740625, (2, 'board'): 1.2375, (1, 'board'): 0.70625, (1, 'topdeck'): 0.18125, (2, 'topdeck'): 0.1625, (3, 'topdeck'): 0.140625})]
# GEMS SUMMARY:  [Counter({3: 7.2625, 2: 3.8375, 0: 3.409375, 1: 1.315625, -1: 0.13125, -2: 0.0125}), Counter({3: 7.371875, 2: 3.89375, 0: 3.090625, 1: 1.315625, -1: 0.140625}), Counter({3: 7.4875, 2: 3.528125, 0: 1.65625, 1: 0.7875, -1: 0.04375, -2: 0.003125}), Counter({3: 7.43125, 2: 3.659375, 0: 1.609375, 1: 0.740625, -1: 0.03125})]
# ON ROUND 5
# ................................................................................................................................................................................................................................................................................................................................/
# R/S 5/0 AVERAGE GAME LENGTH:  126.725
# R/S 5/0 AVERAGE CARDS PURCHASED:  13.015625
# WIN RATES:  [0.08125, 0.121875, 0.36875, 0.428125]
# RESERVATION SUMMARY:  [Counter({(3, 'board'): 1.31875, (2, 'board'): 1.18125, (1, 'board'): 0.934375, (2, 'topdeck'): 0.253125, (3, 'topdeck'): 0.240625, (1, 'topdeck'): 0.221875}), Counter({(3, 'board'): 1.275, (2, 'board'): 1.1625, (1, 'board'): 1.034375, (3, 'topdeck'): 0.290625, (2, 'topdeck'): 0.2125, (1, 'topdeck'): 0.196875}), Counter({(3, 'board'): 1.746875, (2, 'board'): 1.178125, (1, 'board'): 0.753125, (2, 'topdeck'): 0.16875, (1, 'topdeck'): 0.1625, (3, 'topdeck'): 0.14375}), Counter({(3, 'board'): 1.875, (2, 'board'): 1.0875, (1, 'board'): 0.7, (1, 'topdeck'): 0.159375, (3, 'topdeck'): 0.134375, (2, 'topdeck'): 0.109375})]
# GEMS SUMMARY:  [Counter({3: 7.4125, 2: 3.734375, 0: 3.453125, 1: 1.35, -1: 0.146875, -2: 0.00625}), Counter({3: 7.415625, 2: 3.846875, 0: 3.096875, 1: 1.290625, -1: 0.146875}), Counter({3: 7.49375, 2: 3.690625, 0: 1.8, 1: 0.80625, -1: 0.021875}), Counter({3: 7.30625, 2: 3.54375, 0: 1.696875, 1: 0.828125, -1: 0.034375})]
# ................................................................................................................................................................................................................................................................................................................................/
# R/S 5/1 AVERAGE GAME LENGTH:  127.3125
# R/S 5/1 AVERAGE CARDS PURCHASED:  13.0859375
# WIN RATES:  [0.071875, 0.14375, 0.403125, 0.3875]
# RESERVATION SUMMARY:  [Counter({(2, 'board'): 1.271875, (3, 'board'): 1.1875, (1, 'board'): 1.025, (1, 'topdeck'): 0.29375, (3, 'topdeck'): 0.2625, (2, 'topdeck'): 0.240625}), Counter({(3, 'board'): 1.321875, (2, 'board'): 1.228125, (1, 'board'): 0.896875, (2, 'topdeck'): 0.28125, (3, 'topdeck'): 0.234375, (1, 'topdeck'): 0.221875}), Counter({(3, 'board'): 1.6625, (2, 'board'): 1.271875, (1, 'board'): 0.815625, (3, 'topdeck'): 0.165625, (2, 'topdeck'): 0.15, (1, 'topdeck'): 0.14375}), Counter({(3, 'board'): 1.709375, (2, 'board'): 1.13125, (1, 'board'): 0.790625, (3, 'topdeck'): 0.16875, (2, 'topdeck'): 0.1625, (1, 'topdeck'): 0.15625})]
# GEMS SUMMARY:  [Counter({3: 7.5875, 2: 3.653125, 0: 3.215625, 1: 1.41875, -1: 0.134375, -2: 0.003125}), Counter({3: 7.44375, 2: 3.9125, 0: 3.028125, 1: 1.315625, -1: 0.14375, -2: 0.009375}), Counter({3: 7.66875, 2: 3.540625, 0: 1.671875, 1: 0.8625, -1: 0.0125}), Counter({3: 7.415625, 2: 3.46875, 0: 1.815625, 1: 0.8125, -1: 0.040625})]
# ................................................................................................................................................................................................................................................................................................................................/
# R/S 5/2 AVERAGE GAME LENGTH:  127.075
# R/S 5/2 AVERAGE CARDS PURCHASED:  12.959375
# WIN RATES:  [0.075, 0.08125, 0.3875, 0.459375]
# RESERVATION SUMMARY:  [Counter({(3, 'board'): 1.2875, (2, 'board'): 1.078125, (1, 'board'): 1.01875, (3, 'topdeck'): 0.296875, (2, 'topdeck'): 0.275, (1, 'topdeck'): 0.259375}), Counter({(3, 'board'): 1.340625, (2, 'board'): 1.190625, (1, 'board'): 1.071875, (2, 'topdeck'): 0.275, (1, 'topdeck'): 0.234375, (3, 'topdeck'): 0.234375}), Counter({(3, 'board'): 1.76875, (2, 'board'): 1.2625, (1, 'board'): 0.7625, (3, 'topdeck'): 0.146875, (2, 'topdeck'): 0.146875, (1, 'topdeck'): 0.125}), Counter({(3, 'board'): 1.83125, (2, 'board'): 1.021875, (1, 'board'): 0.76875, (3, 'topdeck'): 0.1875, (1, 'topdeck'): 0.121875, (2, 'topdeck'): 0.103125})]
# GEMS SUMMARY:  [Counter({3: 7.428125, 2: 3.875, 0: 3.340625, 1: 1.43125, -1: 0.14375, -2: 0.0125}), Counter({3: 7.43125, 2: 3.803125, 0: 3.003125, 1: 1.35, -1: 0.159375}), Counter({3: 7.621875, 2: 3.53125, 0: 1.790625, 1: 0.928125, -1: 0.053125}), Counter({3: 7.246875, 2: 3.66875, 0: 1.825, 1: 0.75, -1: 0.034375})]
# ON ROUND 6
# ................................................................................................................................................................................................................................................................................................................................/
# R/S 6/0 AVERAGE GAME LENGTH:  126.7875
# R/S 6/0 AVERAGE CARDS PURCHASED:  12.996875
# WIN RATES:  [0.128125, 0.103125, 0.378125, 0.39375]
# RESERVATION SUMMARY:  [Counter({(3, 'board'): 1.346875, (2, 'board'): 1.2625, (1, 'board'): 0.90625, (2, 'topdeck'): 0.228125, (3, 'topdeck'): 0.2125, (1, 'topdeck'): 0.165625}), Counter({(3, 'board'): 1.303125, (2, 'board'): 1.14375, (1, 'board'): 0.959375, (3, 'topdeck'): 0.25625, (2, 'topdeck'): 0.225, (1, 'topdeck'): 0.221875}), Counter({(3, 'board'): 1.81875, (2, 'board'): 1.0625, (1, 'board'): 0.7375, (3, 'topdeck'): 0.159375, (2, 'topdeck'): 0.15, (1, 'topdeck'): 0.13125}), Counter({(3, 'board'): 1.996875, (2, 'board'): 1.003125, (1, 'board'): 0.68125, (1, 'topdeck'): 0.15, (2, 'topdeck'): 0.1375, (3, 'topdeck'): 0.13125})]
# GEMS SUMMARY:  [Counter({3: 7.434375, 2: 3.775, 0: 3.109375, 1: 1.196875, -1: 0.121875, -2: 0.003125}), Counter({3: 7.3125, 2: 3.825, 0: 3.2875, 1: 1.39375, -1: 0.146875, -2: 0.015625}), Counter({3: 7.378125, 2: 3.675, 0: 2.009375, 1: 0.9125, -1: 0.01875}), Counter({3: 7.4, 2: 3.78125, 0: 1.646875, 1: 0.925, -1: 0.028125, -2: 0.0125})]
# ................................................................................................................................................................................................................................................................................................................................/
# R/S 6/1 AVERAGE GAME LENGTH:  125.75
# R/S 6/1 AVERAGE CARDS PURCHASED:  12.97421875
# WIN RATES:  [0.1125, 0.10625, 0.471875, 0.309375]
# RESERVATION SUMMARY:  [Counter({(2, 'board'): 1.3625, (3, 'board'): 1.25625, (1, 'board'): 1.0, (2, 'topdeck'): 0.24375, (1, 'topdeck'): 0.215625, (3, 'topdeck'): 0.190625}), Counter({(3, 'board'): 1.3125, (2, 'board'): 1.20625, (1, 'board'): 1.071875, (3, 'topdeck'): 0.253125, (2, 'topdeck'): 0.209375, (1, 'topdeck'): 0.20625}), Counter({(3, 'board'): 1.840625, (2, 'board'): 1.13125, (1, 'board'): 0.7375, (2, 'topdeck'): 0.15, (3, 'topdeck'): 0.14375, (1, 'topdeck'): 0.1125}), Counter({(3, 'board'): 1.846875, (2, 'board'): 0.975, (1, 'board'): 0.753125, (1, 'topdeck'): 0.184375, (3, 'topdeck'): 0.153125, (2, 'topdeck'): 0.14375})]
# GEMS SUMMARY:  [Counter({3: 7.4625, 2: 3.7, 0: 2.93125, 1: 1.246875, -1: 0.134375, -2: 0.003125}), Counter({3: 7.240625, 2: 3.8875, 0: 3.265625, 1: 1.359375, -1: 0.134375, -2: 0.003125}), Counter({3: 7.490625, 2: 3.5625, 0: 1.546875, 1: 0.60625, -1: 0.01875}), Counter({3: 7.125, 2: 3.70625, 0: 1.953125, 1: 0.740625, -1: 0.034375})]
# ................................................................................................................................................................................................................................................................................................................................/
# R/S 6/2 AVERAGE GAME LENGTH:  126.075
# R/S 6/2 AVERAGE CARDS PURCHASED:  12.90078125
# WIN RATES:  [0.0875, 0.11875, 0.453125, 0.340625]
# RESERVATION SUMMARY:  [Counter({(2, 'board'): 1.359375, (3, 'board'): 1.234375, (1, 'board'): 1.0125, (2, 'topdeck'): 0.221875, (3, 'topdeck'): 0.2, (1, 'topdeck'): 0.146875}), Counter({(2, 'board'): 1.3, (3, 'board'): 1.228125, (1, 'board'): 0.965625, (3, 'topdeck'): 0.265625, (1, 'topdeck'): 0.228125, (2, 'topdeck'): 0.215625}), Counter({(3, 'board'): 1.959375, (2, 'board'): 1.034375, (1, 'board'): 0.68125, (3, 'topdeck'): 0.15625, (2, 'topdeck'): 0.128125, (1, 'topdeck'): 0.1125}), Counter({(3, 'board'): 1.828125, (2, 'board'): 1.103125, (1, 'board'): 0.715625, (3, 'topdeck'): 0.165625, (2, 'topdeck'): 0.140625, (1, 'topdeck'): 0.134375})]
# GEMS SUMMARY:  [Counter({3: 7.503125, 2: 3.725, 0: 3.175, 1: 1.303125, -1: 0.109375, -2: 0.01875}), Counter({3: 7.39375, 2: 3.6375, 0: 3.296875, 1: 1.384375, -1: 0.134375, -2: 0.009375}), Counter({3: 7.571875, 2: 3.5125, 0: 1.59375, 1: 0.796875, -1: 0.01875, -2: 0.003125}), Counter({3: 7.25, 2: 3.640625, 0: 2.021875, 1: 0.79375, -1: 0.034375, -2: 0.00625})]
# ON ROUND 7
# .............................................................
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-ef86466c988b> in <module>()
#      21             new_game = Game(id=i*n_sets_per_round+n_simulations_per_set + j*n_simulations_per_set+k,
#      22                             players=players)
# ---> 23             stalemate = new_game.run()
#      24             # stalemates should be extraordinarily rare and pretty much nonexistent
#      25             if stalemate:
#
# /ntfsl/workspace/splendor_ai/game.py in run(self)
#      89                                 self.turn += 1
#      90                                 player.active_turn=True
# ---> 91                                 player.take_turn()
#      92                                 player.active_turn=False
#      93                                 if self.record_plain_history:
#
# /ntfsl/workspace/splendor_ai/player.py in take_turn(self)
#     208                 self.record_q_state()
#     209
# --> 210                 self.make_turn_action()
#     211
#     212                 self.objective_check()
#
# /ntfsl/workspace/splendor_ai/player.py in make_turn_action(self)
#     320 		"""
#     321                 purchasing_options = self.simulate_purchasing_options()
# --> 322                 reserving_options = self.simulate_reserving_options()
#     323                 gem_taking_options = self.simulate_gem_taking_options()
#     324
#
# /ntfsl/workspace/splendor_ai/player.py in simulate_reserving_options(self)
#     485                         # print(reservation_serializations)
#     486
# --> 487                         predictions = self.ai.make_predictions(reservation_serializations)
#     488 			return {
#     489                                 'predictions':predictions,
#
# /ntfsl/workspace/splendor_ai/ai.py in make_predictions(self, inputs)
#     275
#     276                 for i, q_index in enumerate(self.hyperparameters['output_layers']):
# --> 277                         q_predictions[i] = self.q_networks[i].predict(stacked_network_inputs)[:,0]
#     278
#     279                 return({'win_prediction': win_prediction, 'q_predictions': q_predictions})
#
# /usr/local/lib/python3.5/dist-packages/keras/engine/training.py in predict(self, x, batch_size, verbose, steps)
#    1833         f = self.predict_function
#    1834         return self._predict_loop(f, ins, batch_size=batch_size,
# -> 1835                                   verbose=verbose, steps=steps)
#    1836
#    1837     def train_on_batch(self, x, y,
#
# /usr/local/lib/python3.5/dist-packages/keras/engine/training.py in _predict_loop(self, f, ins, batch_size, verbose, steps)
#    1328                     ins_batch[i] = ins_batch[i].toarray()
#    1329
# -> 1330                 batch_outs = f(ins_batch)
#    1331                 if not isinstance(batch_outs, list):
#    1332                     batch_outs = [batch_outs]
#
# /usr/local/lib/python3.5/dist-packages/keras/backend/tensorflow_backend.py in __call__(self, inputs)
#    2476         session = get_session()
#    2477         updated = session.run(fetches=fetches, feed_dict=feed_dict,
# -> 2478                               **self.session_kwargs)
#    2479         return updated[:len(self.outputs)]
#    2480
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     903     try:
#     904       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 905                          run_metadata_ptr)
#     906       if run_metadata:
#     907         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1138     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1139       results = self._do_run(handle, final_targets, final_fetches,
# -> 1140                              feed_dict_tensor, options, run_metadata)
#    1141     else:
#    1142       results = []
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1319     if handle is None:
#    1320       return self._do_call(_run_fn, feeds, fetches, targets, options,
# -> 1321                            run_metadata)
#    1322     else:
#    1323       return self._do_call(_prun_fn, handle, feeds, fetches)
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1325   def _do_call(self, fn, *args):
#    1326     try:
# -> 1327       return fn(*args)
#    1328     except errors.OpError as e:
#    1329       message = compat.as_text(e.message)
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in _run_fn(feed_dict, fetch_list, target_list, options, run_metadata)
#    1310       self._extend_graph()
#    1311       return self._call_tf_sessionrun(
# -> 1312           options, feed_dict, fetch_list, target_list, run_metadata)
#    1313
#    1314     def _prun_fn(handle, feed_dict, fetch_list):
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in _call_tf_sessionrun(self, options, feed_dict, fetch_list, target_list, run_metadata)
#    1418         return tf_session.TF_Run(
#    1419             self._session, options, feed_dict, fetch_list, target_list,
# -> 1420             status, run_metadata)
#    1421
#    1422   def _call_tf_sessionprun(self, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:

# %%
# save historic data
import pickle
with open('{run_name}_game_data.dat'.format(run_name=run_name), 'wb') as f:
    pickle.dump(game_data, f)
    
with open('{run_name}_duration_data.dat'.format(run_name=run_name), 'wb') as f:
    pickle.dump(set_durations, f)

# %%
# players[0].ai.load_models('run6_player_0_round_', 1)

# %%
from collections import Mapping, Container 
from sys import getsizeof

def deep_getsizeof(o, ids): 

    d = deep_getsizeof
    if id(o) in ids:
        return 0

    r = getsizeof(o)
    ids.add(id(o))

    if isinstance(o, str) or isinstance(0, bytes):
        return r
    
    if isinstance(o, np.ndarray):
        return r

    if isinstance(o, Mapping):
        return r + sum(d(k, ids) + d(v, ids) for k, v in o.items())

    if isinstance(o, Container):
        return r + sum(d(x, ids) for x in o)

    return r

deep_getsizeof(game_data, set())
# deep_getsizeof(players[0].extended_serialized_action_history[0], set())

# for k in list(locals().keys()):
#    v = locals()[k]
#    size = deep_getsizeof(v, set())
#    if size > 100000:
#        print(k, ':', size)

# %%
# players[1].reset(reset_extended_history=True)
# for k in dir(players[1]):
#    v = getattr(players[1], k)
#    if isinstance(v, (list, dict)):
#        print(k, len(v))

# %%
#new_game = Game(id=i*200 + j*100+1.1, players=players)

# %%
#for k in dir(players[2]):
#    v = getattr(players[2], k)
#    if isinstance(v, (list, dict)):
#        print(k, len(v))

# %%
#len(players[0].ai.extended_serialized_history)

# %% [markdown]
# # NOTES
#
# Runs are complete. Data can be analyzed in a different environment. Tweaks may be made for future runs based on simulation results from loaded models.
